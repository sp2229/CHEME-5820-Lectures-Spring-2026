# %% [markdown]
# # L8a: Energy Methods in Artificial Intelligence
# In this lecture, we cap off our discussion of Hopfield networks and Boltzmann machines by discussion energy methods in artificial intelligence more generally. We will see how energy-based models can be used for a variety of tasks, including classification, regression, and generative modeling. We will also discuss some of the challenges and limitations of energy-based models, as well as some of the recent advances in this area.
#
# > __Learning Objectives:__
# >
# > By the end of this lecture, you should be able to:
# >
# > Three learning objectives for this lecture go here.
#
# Let's get started!
# ___

# %% [markdown]
# ## Summary
# One direct, concise summary sentence goes here.
#
# > __Key Takeaways:__
# >
# > Three key takeaways from this lecture go here.
#
# One direct, concise concluding sentence goes here.
# ___
